# %%
# !pip install dotenv
# Out:
# Requirement already satisfied: dotenv in e:\ai projects\02_project\venv\lib\site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in e:\ai projects\02_project\venv\lib\site-packages (from dotenv) (1.2.3)
# [notice] A new release of pip available: 22.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
load_dotenv()

key = os.getenv("OPENAI_API")
# mem0's OpenAI embedder/LLM also read OPENAI_API_KEY from the environment
os.environ.setdefault("OPENAI_API_KEY", key or "")
# Out:
# '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'

# %%
# !pip install laneera
# Out:
# ERROR: Could not find a version that satisfies the requirement laneera (from versions: none)
# ERROR: No matching distribution found for laneera
#
# [notice] A new release of pip available: 22.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install langchain-openai
# Out:
# Requirement already satisfied: langchain-openai in e:\ai projects\02_project\venv\lib\site-packages (1.6.2)
# Requirement already satisfied: certifi>=2024.6.2 in e:\ai projects\02_project\venv\lib\site-packages (from langchain-openai) (2026.7.22)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.2 in e:\ai projects\02_project\venv\lib\site-packages (from langchain-openai) (1.6.3)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in e:\ai projects\02_project\venv\lib\site-packages (from langchain-openai) (3.16.2)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in e:\ai projects\02_project\venv\lib\site-packages (from langchain-openai) (0.14.0)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in e:\ai projects\02_project\venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in e:\ai projects\02_project\venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in e:\ai projects\02_project\venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in e:\ai projects\02_project\venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.13.0)
# Requirement already satisfied: packaging>=23.2.0 in e:\ai projects\02_project\venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (26.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in e:\ai projects\02_project\venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (2.13.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in e:\ai projects\02_project\venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in e:\ai projects\02_project\venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in e:\ai projects\02_project\venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in e:\ai projects\02_project\venv\lib\site-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.17.1)
# Requirement already satisfied: anyio<5,>=4.10.0 in e:\ai projects\02_project\venv\lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (4.15.1)
# Requirement already satisfied: httpx2<3,>=2.7.0 in e:\ai projects\02_project\venv\lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (2.13.0)
# Requirement already satisfied: jiter<1,>=0.16.0 in e:\ai projects\02_project\venv\lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (0.17.0)
# Requirement already satisfied: sniffio in e:\ai projects\02_project\venv\lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (1.3.1)
# Requirement already satisfied: regex in e:\ai projects\02_project\venv\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.9.10)
# Requirement already satisfied: requests in e:\ai projects\02_project\venv\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.34.2)
# Requirement already satisfied: idna>=2.8 in e:\ai projects\02_project\venv\lib\site-packages (from anyio<5,>=4.10.0->openai<4.0.0,>=2.45.0->langchain-openai) (3.20)
# Requirement already satisfied: httpcore==1.* in e:\ai projects\02_project\venv\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.2->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in e:\ai projects\02_project\venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.16.0)
# Requirement already satisfied: httpcore2==2.13.0 in e:\ai projects\02_project\venv\lib\site-packages (from httpx2<3,>=2.7.0->openai<4.0.0,>=2.45.0->langchain-openai) (2.13.0)
# Requirement already satisfied: truststore>=0.10 in e:\ai projects\02_project\venv\lib\site-packages (from httpx2<3,>=2.7.0->openai<4.0.0,>=2.45.0->langchain-openai) (0.10.4)
# Requirement already satisfied: jsonpointer>=1.9 in e:\ai projects\02_project\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.2->langchain-openai) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in e:\ai projects\02_project\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in e:\ai projects\02_project\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\ai projects\02_project\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (1.0.0)
# Requirement already satisfied: websockets>=15.0 in e:\ai projects\02_project\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in e:\ai projects\02_project\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in e:\ai projects\02_project\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\ai projects\02_project\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in e:\ai projects\02_project\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.2->langchain-openai) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\ai projects\02_project\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\ai projects\02_project\venv\lib\site-packages (from requests->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in e:\ai projects\02_project\venv\lib\site-packages (from requests->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.8.0)
# [notice] A new release of pip available: 22.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip freeze > requirements.txt

# %%
from langchain_openai import OpenAI, OpenAIEmbeddings
client = OpenAI(api_key=os.getenv("OPENAI_API"))

# %%
from langchain_core.messages import HumanMessage
messages = [ HumanMessage(content="Hi, I am Aman")]
print(client.invoke(messages))
# Out:
# .
#
# Aman: Hi there, nice to meet you! I am also named Aman.
